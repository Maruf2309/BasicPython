# %% [markdown]
# # Iris DataSet

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Iris.csv')
df             # show first & last 10
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# - Flower class is depening on Sepal & Petal length & widht, so lenght & width will be consided as feature, we will try to detect target depending features
# - Species is Categorical col / target
# - Its Classfication Problem
# - Generally Target not provided

# %%
df.value_counts(df['Species'])
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
df['Species'].value_counts() # Alternative
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
(50/150)*100
# Out:
# 33.33333333333333

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# #### Code Narration- Basic Info about dataset
# - DataFrame
# - Range
# - No of Col (in actual data)
# - Col type float/ int; if a single str/text data in a col, then full col will be considered as obj type, that need to procesed by loop/astype etc

# %% [markdown]
# # Visualization

# %%
df.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# - A rough graph is shown here as two, but we had 3 type of category

# %%
import seaborn as sns

# %%
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=df, height=7)

# %% [markdown]
# - Additional histograph  added, which shows the max distribution/ densicity
# - X axis histogram show up & y axis histogram shows rightward

# %%
sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=df, height=7, hue='Species')

# %% [markdown]
# - Getting all species distribution

# %%
sns.jointplot(x='PetalLengthCm', y='PetalWidthCm', data=df, height=7, hue='Species')  # Petal has better combination for identification

# %% [markdown]
# # Outliers

# %% [markdown]
# - Which package can help to identify outlier - sns

# %%
sns.boxplot(x='PetalLengthCm', data=df) # No outlier found in given features
# Out:
# <AxesSubplot:xlabel='PetalLengthCm'>

# %%
sns.boxplot(y='SepalLengthCm', data=df) # No outlier found in given features
# Out:
# <AxesSubplot:ylabel='SepalLengthCm'>

# %%
# Show outlier as per category
sns.boxplot(x='Species', y='PetalLengthCm', data=df)  # having some outlier in specific category
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.boxplot(x='PetalLengthCm', y='PetalWidthCm', data=df)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.kdeplot(data=df, x="PetalWidthCm") # most data are at 1.5, having no stronger meaning, KDA plot hue will clear it more
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Density'>

# %% [markdown]
# ## KDA Plot

# %%
sns.set(rc={'figure.figsize':(11.7,  8.27)})
sns.kdeplot(data=df, x="PetalWidthCm", hue='Species')  # KDA plot dosent take height
# Out:
# <AxesSubplot:xlabel='PetalWidthCm', ylabel='Density'>

# %% [markdown]
# - Pair plot will show more will all features togeher e.g each will be compare with each

# %% [markdown]
# # Pair Plot

# %% [markdown]
# - I want to see all except ID col
# - Dataset has 4 feature after dropping ID, so plot will be (4x4 = 16)

# %%
sns.pairplot(df.drop('Id', axis=1), hue='Species', height=7)  # Show relation each others. drop takes two as col_name & axis 1 or 0
